# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
# Matplotlib is a Python library used for creating static, animated, and interactive visualizations. It is widely used for plotting data and generating
# charts to aid in data analysis.

#  Why is it used?
# - To visualize data in various formats (e.g., line plots, bar plots).
# - Helps in understanding trends, distributions, and patterns in data.

# Five Plots in Matplotlib (Pyplot module):
# 1. Line Plot (`plt.plot()`)
# 2. Bar Plot (`plt.bar()`)
# 3. Scatter Plot (`plt.scatter()`)
# 4. Histogram (`plt.hist()`)
# 5. Box Plot (`plt.boxplot()`)

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
# A **scatter plot** is a graph that uses dots to represent the relationship between two numerical variables.
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
# The subplot() function in Matplotlib is used to create multiple plots in a single figure by dividing the figure into a grid of subplots.
x1, y1 = np.array([0, 1, 2, 3, 4, 5]) , np.array([0, 100, 200, 300, 400, 500])
x2, y2 = np.array([0, 1, 2, 3, 4, 5]) , np.array([50, 20, 40, 20, 60, 70])
x3,y3  = np.array([0, 1, 2, 3, 4, 5]) , np.array([10, 20, 30, 40, 50, 60])
x4,y4 = np.array([0, 1, 2, 3, 4, 5]) , np.array([200, 350, 250, 550, 450, 150])
plt .figure(figsize= (10,8))
plt.subplot(2, 2, 1)
plt.plot(x1,y1 ,c='red')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.subplot(2, 2, 2)
plt.plot(x2,y2 ,c='blue')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.subplot(2, 2, 3)
plt.plot(x3,y3 ,c='black')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.subplot(2, 2, 4)
plt.plot(x4,y4 ,c='pink')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
# Bar plot
# A bar plot displays categorical data with rectangular bars, where the height(or length) of the bar represents the value.
# Uses:
# To compare quantities across categories.
# To visualize frequency, counts, or other categorical data.
# Horizontal Bar Plot
# A variant where bars are displayed horizontally, useful when category labels are too long or data comparison is easier
# this way.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company, profit)
plt.xlabel("Profit ($)")
plt.ylabel("Company")
plt.show()

# %%
plt.barh(company, profit)
plt.xlabel("Company")
plt.ylabel("Profit ($)")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
# A box plot is a graphical summary of data distribution showing the median, quartiles, and potential outliers. It is used to compare datasets,
# identify variability, and detect unusual values.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data=[box1,box2]
plt.boxplot(data)
plt.show()
